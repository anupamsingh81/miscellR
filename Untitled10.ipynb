# %%
x = c(3:10)
y = c(90:100)
library(BEST)
z = BESTmcmc(y,x)
summary(z)
# Out:
# Processing function input.......
#
# Done.
#
# Compiling model graph
#    Resolving undeclared variables
#    Allocating nodes
# Graph information:
#    Observed stochastic nodes: 19
#    Unobserved stochastic nodes: 5
#    Total graph size: 61
#
# Initializing model
#
# Adaptive phase, 500 iterations x 3 chains
# If no progress bar appears JAGS has decided not to adapt
#
#
#  Burn-in phase, 1000 iterations x 3 chains
#
#
# Sampling from joint posterior, 33334 iterations x 3 chains
#
#
# MCMC took 0.435 minutes.
#            mean median   mode HDI% HDIlo HDIup compVal %>compVal
# mu1       95.00 95.000 94.942   95 92.56 97.45
# mu2        6.50  6.502  6.533   95  4.23  8.84
# muDiff    88.50 88.502 88.556   95 85.23 91.90       0     100.0
# sigma1     3.75  3.564  3.271   95  2.08  5.88
# sigma2     2.99  2.742  2.420   95  1.38  5.13
# sigmaDiff  0.76  0.795  0.761   95 -2.30  3.89       0      73.5
# nu        36.18 27.718 12.171   95  1.46 96.44
# ...

# %%
plot(z)
# Out:
# Plot with title “Difference of Means”
